# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
def getDecoys_pos2(df, d1_max, d1_min, d2_max, d2_min):
    
    # Get range difference between max-min attributes
    r1 = d1_max - d1_min 
    r2 = d2_max - d2_min 
    
    #c = (1/3) 
    
    # Get item 'A'
    A1 = d1_min + (r1/3) 
    A2 = d2_max - (r2/3)
    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"
    
    # Get item 'B'
    B1 = d1_max - (r1/3)
    B2 = d2_min + (r2/3)
    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"
    
    # Get Phantom decoy A (P_A)
    P_A1 = d1_min + (r1/3)
    P_A2 = d2_min + 4*(r2/5)
    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"
    
    # Get P_B
    P_B1 = d1_min + 4*(r1/5)
    P_B2 = d2_min + (r2/3)
    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"
    
    # Get Attraction decoy A (A_A)
    A_A1 = A1 #- (r1/6)
    A_A2 = A2 - (r2/6)
    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"
    
    # Get A_B
    A_B1 = B1 - (r1/6)
    A_B2 = B2 #- (r2/6)
    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"

    # Get Similarity decoy A (S_A)
    S_A1 = A1 + (r1/15)
    S_A2 = A2 - (r2/15)
    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"
    
    # Get S_B 
    S_B1 = B1 - (r1/15)
    S_B2 = B2 + (r2/15)
    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"
    
    # Get Compromise decoy A (C_A)
    C_A1 = d1_min
    C_A2 = d2_max
    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"
    
    # Get C_B 
    C_B1 = d1_max
    C_B2 = d2_min
    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"
    
    decoy_data = pd.DataFrame(data={'A': A, 'B': B, 'P_A': P_A, 'P_B': P_B, 'A_A': A_A, 'A_B': A_B, 'S_A': S_A, 'S_B': S_B, 'C_A': C_A, 'C_B': C_B}, index=range(1))
    df = df.append(decoy_data, ignore_index = True)
    
    return df

# %%
df_decoys_pos = pd.DataFrame()

df_decoys_pos = getDecoys_pos2(df_decoys_pos, 2500, 500, 12, 3)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 90, 75, 170, 100)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 350, 80, 12, 4)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 20000, 5300, 12, 3)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 18, 12, 24, 6)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 120, 60, 15, 4)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 3000, 1300, 3, 0.4)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 21, 14, 70, 30)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 1500, 1000, 15, 3)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 12000, 10000, 10, 6)

df_decoys_pos = getDecoys_pos2(df_decoys_pos, 250, 40, 36, 6)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 40, 20, 24, 6)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 99, 70, 600, 400)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 33, 10, 36, 12)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 20000, 12000, 50000, 30000)

df_decoys_pos = getDecoys_pos2(df_decoys_pos, 12, 3, 18, 6)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 2800, 1200, 1900, 1200)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 40, 13, 16, 2)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 90, 42, 60, 20)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 12, 7, 24, 12)

df_decoys_pos = getDecoys_pos2(df_decoys_pos, 90, 20, 700, 300)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 160, 100, 45, 15)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 16, 4, 12, 6)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 1000, 100, 390, 120)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 100, 40, 30, 12)

df_decoys_pos = getDecoys_pos2(df_decoys_pos, 900, 250, 90, 20)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 12, 3, 480, 300)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 25, 10, 300, 200)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 60, 30, 6000, 3800)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 350, 200, 16, 4)

df_decoys_pos = getDecoys_pos2(df_decoys_pos, 21, 9, 900, 300)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 12, 3, 15, 3)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 30, 12, 3500, 2300)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 9, 3, 24, 6)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 3000, 1800, 3, 1.5)

df_decoys_pos = getDecoys_pos2(df_decoys_pos, 21, 6, 12, 3)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 120, 60, 9, 3)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 1800, 600, 6, 1)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 190, 100, 7, 1)
df_decoys_pos = getDecoys_pos2(df_decoys_pos, 45, 20, 100, 40)

df_decoys_pos.head(40)
# Out:
#                        A                     B                  P_A  \
# 0         (1166.67, 9.0)        (1833.33, 6.0)      (1166.67, 10.2)
# 1         (80.0, 146.67)        (85.0, 123.33)        (80.0, 156.0)
# 2          (170.0, 9.33)         (260.0, 6.67)        (170.0, 10.4)
# 3         (10200.0, 9.0)        (15100.0, 6.0)      (10200.0, 10.2)
# 4           (14.0, 18.0)          (16.0, 12.0)         (14.0, 20.4)
# 5          (80.0, 11.33)         (100.0, 7.67)         (80.0, 12.8)
# 6        (1866.67, 2.13)       (2433.33, 1.27)      (1866.67, 2.48)
# 7         (16.33, 56.67)        (18.67, 43.33)        (16.33, 62.0)
# 8        (1166.67, 11.0)        (1333.33, 7.0)      (1166.67, 12.6)
# 9       (10666.67, 8.67)      (11333.33, 7.33)      (10666.67, 9.2)
# 10         (110.0, 26.0)         (180.0, 16.0)        (110.0, 30.0)
# 11         (26.67, 18.0)         (33.33, 12.0)        (26.67, 20.4)
# 12       (79.67, 533.33)       (89.33, 466.67)       (79.67, 560.0)
# 13         (17.67, 28.0)         (25.33, 20.0)        (17.67, 31.2)
# 14  (14666.67, 43333.33)  (17333.33, 36666.67)  (14666.67, 46000.0)
# 15           (6.0, 14.0)           (9.0, 10.0)          (6.0, 15.6)
# 16    (1733.33, 1666.67)    (2266.67, 1433.33)    (1733.33, 1760.0)
# 17         (22.0, 11.33)          (31.0, 6.67)         (22.0, 13.2)
# 18         (58.0, 46.67)         (74.0, 33.33)         (58.0, 52.0)
# 19          (8.67, 20.0)         (10.33, 16.0)         (8.67, 21.6)
# 20       (43.33, 566.67)       (66.67, 433.33)       (43.33, 620.0)
# 21         (120.0, 35.0)         (140.0, 25.0)        (120.0, 39.0)
# 22           (8.0, 10.0)           (12.0, 8.0)          (8.0, 10.8)
# 23        (400.0, 300.0)        (700.0, 210.0)       (400.0, 336.0)
# 24          (60.0, 24.0)          (80.0, 18.0)         (60.0, 26.4)
# 25       (466.67, 66.67)       (683.33, 43.33)       (466.67, 76.0)
# 26          (6.0, 420.0)          (9.0, 360.0)         (6.0, 444.0)
# 27        (15.0, 266.67)        (20.0, 233.33)        (15.0, 280.0)
# 28       (40.0, 5266.67)       (50.0, 4533.33)       (40.0, 5560.0)
# 29         (250.0, 12.0)          (300.0, 8.0)        (250.0, 13.6)
# 30         (13.0, 700.0)         (17.0, 500.0)        (13.0, 780.0)
# 31           (6.0, 11.0)            (9.0, 7.0)          (6.0, 12.6)
# 32        (18.0, 3100.0)        (24.0, 2700.0)       (18.0, 3260.0)
# 33           (5.0, 18.0)           (7.0, 12.0)          (5.0, 20.4)
# 34         (2200.0, 2.5)         (2600.0, 2.0)        (2200.0, 2.7)
# 35           (11.0, 9.0)           (16.0, 6.0)         (11.0, 10.2)
# 36           (80.0, 7.0)          (100.0, 5.0)          (80.0, 7.8)
# 37        (1000.0, 4.33)        (1400.0, 2.67)        (1000.0, 5.0)
# 38          (130.0, 5.0)          (160.0, 3.0)         (130.0, 5.8)
# 39         (28.33, 80.0)         (36.67, 60.0)        (28.33, 88.0)
#
#                     P_B                  A_A                  A_B  \
# 0         (2100.0, 6.0)       (1166.67, 7.5)        (1500.0, 6.0)
# 1        (87.0, 123.33)        (80.0, 135.0)       (82.5, 123.33)
# 2         (296.0, 6.67)         (170.0, 8.0)        (215.0, 6.67)
# 3        (17060.0, 6.0)       (10200.0, 7.5)       (12650.0, 6.0)
# 4          (16.8, 12.0)         (14.0, 15.0)         (15.0, 12.0)
# 5         (108.0, 7.67)          (80.0, 9.5)         (90.0, 7.67)
# 6        (2660.0, 1.27)       (1866.67, 1.7)       (2150.0, 1.27)
# 7         (19.6, 43.33)        (16.33, 50.0)        (17.5, 43.33)
# 8         (1400.0, 7.0)       (1166.67, 9.0)        (1250.0, 7.0)
# 9       (11600.0, 7.33)      (10666.67, 8.0)      (11000.0, 7.33)
# 10        (208.0, 16.0)        (110.0, 21.0)        (145.0, 16.0)
# 11         (36.0, 12.0)        (26.67, 15.0)         (30.0, 12.0)
# 12       (93.2, 466.67)       (79.67, 500.0)       (84.5, 466.67)
# 13         (28.4, 20.0)        (17.67, 24.0)         (21.5, 20.0)
# 14  (18400.0, 36666.67)  (14666.67, 40000.0)  (16000.0, 36666.67)
# 15         (10.2, 10.0)          (6.0, 12.0)          (7.5, 10.0)
# 16    (2480.0, 1433.33)    (1733.33, 1550.0)    (2000.0, 1433.33)
# 17         (34.6, 6.67)          (22.0, 9.0)         (26.5, 6.67)
# 18        (80.4, 33.33)         (58.0, 40.0)        (66.0, 33.33)
# 19         (11.0, 16.0)         (8.67, 18.0)          (9.5, 16.0)
# 20       (76.0, 433.33)       (43.33, 500.0)       (55.0, 433.33)
# 21        (148.0, 25.0)        (120.0, 30.0)        (130.0, 25.0)
# 22          (13.6, 8.0)           (8.0, 9.0)          (10.0, 8.0)
# 23       (820.0, 210.0)       (400.0, 255.0)       (550.0, 210.0)
# 24         (88.0, 18.0)         (60.0, 21.0)         (70.0, 18.0)
# 25       (770.0, 43.33)       (466.67, 55.0)       (575.0, 43.33)
# 26        (10.2, 360.0)         (6.0, 390.0)         (7.5, 360.0)
# 27       (22.0, 233.33)        (15.0, 250.0)       (17.5, 233.33)
# 28      (54.0, 4533.33)       (40.0, 4900.0)      (45.0, 4533.33)
# 29         (320.0, 8.0)        (250.0, 10.0)         (275.0, 8.0)
# 30        (18.6, 500.0)        (13.0, 600.0)        (15.0, 500.0)
# 31          (10.2, 7.0)           (6.0, 9.0)           (7.5, 7.0)
# 32       (26.4, 2700.0)       (18.0, 2900.0)       (21.0, 2700.0)
# 33          (7.8, 12.0)          (5.0, 15.0)          (6.0, 12.0)
# 34        (2760.0, 2.0)       (2200.0, 2.25)        (2400.0, 2.0)
# 35          (18.0, 6.0)          (11.0, 7.5)          (13.5, 6.0)
# 36         (108.0, 5.0)          (80.0, 6.0)          (90.0, 5.0)
# 37       (1560.0, 2.67)        (1000.0, 3.5)       (1200.0, 2.67)
# 38         (172.0, 3.0)         (130.0, 4.0)         (145.0, 3.0)
# 39         (40.0, 60.0)        (28.33, 70.0)         (32.5, 60.0)
#
#                    S_A                 S_B             C_A             C_B
# 0        (1300.0, 8.4)       (1700.0, 6.6)       (500, 12)       (2500, 3)
# 1        (81.0, 142.0)       (84.0, 128.0)       (75, 170)       (90, 100)
# 2         (188.0, 8.8)        (242.0, 7.2)        (80, 12)        (350, 4)
# 3       (11180.0, 8.4)      (14120.0, 6.6)      (5300, 12)      (20000, 3)
# 4         (14.4, 16.8)        (15.6, 13.2)        (12, 24)         (18, 6)
# 5         (84.0, 10.6)         (96.0, 8.4)        (60, 15)        (120, 4)
# 6       (1980.0, 1.96)      (2320.0, 1.44)       (1300, 3)     (3000, 0.4)
# 7         (16.8, 54.0)        (18.2, 46.0)        (14, 70)        (21, 30)
# 8       (1200.0, 10.2)       (1300.0, 7.8)      (1000, 15)       (1500, 3)
# 9       (10800.0, 8.4)      (11200.0, 7.6)     (10000, 10)      (12000, 6)
# 10       (124.0, 24.0)       (166.0, 18.0)        (40, 36)        (250, 6)
# 11        (28.0, 16.8)        (32.0, 13.2)        (20, 24)         (40, 6)
# 12       (81.6, 520.0)       (87.4, 480.0)       (70, 600)       (99, 400)
# 13        (19.2, 26.4)        (23.8, 21.6)        (10, 36)        (33, 12)
# 14  (15200.0, 42000.0)  (16800.0, 38000.0)  (12000, 50000)  (20000, 30000)
# 15         (6.6, 13.2)         (8.4, 10.8)         (3, 18)         (12, 6)
# 16    (1840.0, 1620.0)    (2160.0, 1480.0)    (1200, 1900)    (2800, 1200)
# 17        (23.8, 10.4)         (29.2, 7.6)        (13, 16)         (40, 2)
# 18        (61.2, 44.0)        (70.8, 36.0)        (42, 60)        (90, 20)
# 19         (9.0, 19.2)        (10.0, 16.8)         (7, 24)        (12, 12)
# 20       (48.0, 540.0)       (62.0, 460.0)       (20, 700)       (90, 300)
# 21       (124.0, 33.0)       (136.0, 27.0)       (100, 45)       (160, 15)
# 22          (8.8, 9.6)         (11.2, 8.4)         (4, 12)         (16, 6)
# 23      (460.0, 282.0)      (640.0, 228.0)      (100, 390)     (1000, 120)
# 24        (64.0, 22.8)        (76.0, 19.2)        (40, 30)       (100, 12)
# 25       (510.0, 62.0)       (640.0, 48.0)       (250, 90)       (900, 20)
# 26        (6.6, 408.0)        (8.4, 372.0)        (3, 480)       (12, 300)
# 27       (16.0, 260.0)       (19.0, 240.0)       (10, 300)       (25, 200)
# 28      (42.0, 5120.0)      (48.0, 4680.0)      (30, 6000)      (60, 3800)
# 29       (260.0, 11.2)        (290.0, 8.8)       (200, 16)        (350, 4)
# 30       (13.8, 660.0)       (16.2, 540.0)        (9, 900)       (21, 300)
# 31         (6.6, 10.2)          (8.4, 7.8)         (3, 15)         (12, 3)
# 32      (19.2, 3020.0)      (22.8, 2780.0)      (12, 3500)      (30, 2300)
# 33         (5.4, 16.8)         (6.6, 13.2)         (3, 24)          (9, 6)
# 34       (2280.0, 2.4)       (2520.0, 2.1)       (1800, 3)     (3000, 1.5)
# 35         (12.0, 8.4)         (15.0, 6.6)         (6, 12)         (21, 3)
# 36         (84.0, 6.6)         (96.0, 5.4)         (60, 9)        (120, 3)
# 37       (1080.0, 4.0)       (1320.0, 3.0)        (600, 6)       (1800, 1)
# 38        (136.0, 4.6)        (154.0, 3.4)        (100, 7)        (190, 1)
# 39        (30.0, 76.0)        (35.0, 64.0)       (20, 100)        (45, 40)

# %%
# Visualization of decoys (positive-monotonic)

# Item '1' in the table above.
x = np.array([80, 85, 80, 87, 80, 82.5, 81, 84, 75, 90])
x = x/10
y = np.array([146.6, 123.3, 156., 123.3, 135, 123.3, 142, 128, 170, 100])
y = (y/10) - 8

print(x)
print(y)

print("A: " + str((x[0], y[0])))
print("B: " + str((x[1], y[1])))
print("P_A: " + str((x[2], y[2])))
print("P_B: " + str((x[3], y[3])))
print("A_A: " + str((x[4], y[4])))
print("A_B: " + str((x[5], y[5])))
print("S_A: " + str((x[6], y[6])))
print("S_B: " + str((x[7], y[7])))
print("C_A: " + str((x[8], y[8])))
print("C_B: " + str((x[9], y[9])))



plt.subplots(figsize=(9, 9))
plt.scatter(x, y)
plt.annotate("A", (x[0], y[0]))
plt.annotate("B", (x[1], y[1]))
plt.annotate("P_A", (x[2], y[2]))
plt.annotate("P_B", (x[3], y[3]))
plt.annotate("A_A", (x[4], y[4]))
plt.annotate("A_B", (x[5], y[5]))
plt.annotate("S_A", (x[6], y[6]))
plt.annotate("S_B", (x[7], y[7]))
plt.annotate("C_A", (x[8], y[8]))
plt.annotate("C_B", (x[9], y[9]))

plt.show()
# Out:
# [8.   8.5  8.   8.7  8.   8.25 8.1  8.4  7.5  9.  ]
# [6.66 4.33 7.6  4.33 5.5  4.33 6.2  4.8  9.   2.  ]
# A: (8.0, 6.66)
# B: (8.5, 4.33)
# P_A: (8.0, 7.6)
# P_B: (8.7, 4.33)
# A_A: (8.0, 5.5)
# A_B: (8.25, 4.33)
# S_A: (8.1, 6.199999999999999)
# S_B: (8.4, 4.800000000000001)
# C_A: (7.5, 9.0)
# C_B: (9.0, 2.0)

# %%
def getDecoys_Pos_FixSim(df, d1_max, d1_min, d2_max, d2_min):
    
    # Get range difference between max-min attributes
    r1 = d1_max - d1_min 
    r2 = d2_max - d2_min 
    
    #c = (1/3) 
    
    # Get item 'A'
    A1 = d1_min + (r1/3) 
    A2 = d2_max - (r2/3)
    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"
    
    # Get item 'B'
    B1 = d1_max - (r1/3)
    B2 = d2_min + (r2/3)
    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"
    
    # Get Phantom decoy A (P_A)
    P_A1 = d1_min + (r1/3)
    P_A2 = d2_min + 4*(r2/5)
    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"
    
    # Get P_B
    P_B1 = d1_min + 4*(r1/5)
    P_B2 = d2_min + (r2/3)
    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"
    
    # Get Attraction decoy A (A_A)
    A_A1 = A1 #- (r1/6)
    A_A2 = A2 - (r2/6)
    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"
    
    # Get A_B
    A_B1 = B1 - (r1/6)
    A_B2 = B2 #- (r2/6)
    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"

    # Get Similarity decoy A (S_A)
    S_A1 = A1 - (r1/15)
    S_A2 = A2 + (r2/15)
    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"
    
    # Get S_B 
    S_B1 = B1 + (r1/15)
    S_B2 = B2 - (r2/15)
    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"
    
    # Get Compromise decoy A (C_A)
    C_A1 = d1_min
    C_A2 = d2_max
    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"
    
    # Get C_B 
    C_B1 = d1_max
    C_B2 = d2_min
    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"
    print("["+ str(A1) + ", " + str(B1) + ", " + str(P_A1) + ", " + str(P_B1) + ", " + str(A_A1) + ", " + str(A_B1) + ", " + str(S_A1) + ", " + str(S_B1) + 
        ", " + str(C_A1) + ", " + str(C_B1) +"], [" +
        str(A2) + ", " + str(B2) +
        ", " + str(P_A2) + ", " + str(P_B2) +
        ", " + str(A_A2) + ", " + str(A_B2) + 
        ", " + str(S_A2) + ", " + str(S_B2) + 
        ", " + str(C_A2) + ", " + str(C_B2) + "]")
    decoy_data = pd.DataFrame(data={'A': A, 'B': B, 'P_A': P_A, 'P_B': P_B, 'A_A': A_A, 'A_B': A_B, 'S_A': S_A, 'S_B': S_B, 'C_A': C_A, 'C_B': C_B}, index=range(1))
    df = df.append(decoy_data, ignore_index = True)
    
    return df

# %%
df_decoys_fixsim = pd.DataFrame()

df_decoys_fixsim = getDecoys_Pos_FixSim(df_decoys_fixsim, 21, 6, 12, 3)

df_decoys_fixsim.head()
# Out:
# [11.0, 16.0, 11.0, 18.0, 11.0, 13.5, 10.0, 17.0, 6, 21], [9.0, 6.0, 10.2, 6.0, 7.5, 6.0, 9.6, 5.4, 12, 3]
#              A            B           P_A          P_B          A_A  \
# 0  (11.0, 9.0)  (16.0, 6.0)  (11.0, 10.2)  (18.0, 6.0)  (11.0, 7.5)
#
#            A_B          S_A          S_B      C_A      C_B
# 0  (13.5, 6.0)  (10.0, 9.6)  (17.0, 5.4)  (6, 12)  (21, 3)

# %%
x = np.array([11, 16, 11, 18, 11, 13.5, 10, 17, 6, 21])
#x = x/10
y = np.array([9, 6, 10.2, 6, 7.5, 6, 9.6, 5.4, 12, 3])
#y = (y/10) - 8

print(x)
print(y)

print("A: " + str((x[0], y[0])))
print("B: " + str((x[1], y[1])))
print("P_A: " + str((x[2], y[2])))
print("P_B: " + str((x[3], y[3])))
print("A_A: " + str((x[4], y[4])))
print("A_B: " + str((x[5], y[5])))
print("S_A: " + str((x[6], y[6])))
print("S_B: " + str((x[7], y[7])))
print("C_A: " + str((x[8], y[8])))
print("C_B: " + str((x[9], y[9])))



plt.subplots(figsize=(9, 9))
plt.scatter(x, y)
plt.annotate("A", (x[0], y[0]))
plt.annotate("B", (x[1], y[1]))
plt.annotate("P_A", (x[2], y[2]))
plt.annotate("P_B", (x[3], y[3]))
plt.annotate("A_A", (x[4], y[4]))
plt.annotate("A_B", (x[5], y[5]))
plt.annotate("S_A", (x[6], y[6]))
plt.annotate("S_B", (x[7], y[7]))
plt.annotate("C_A", (x[8], y[8]))
plt.annotate("C_B", (x[9], y[9]))

plt.show()
# Out:
# [11.  16.  11.  18.  11.  13.5 10.  17.   6.  21. ]
# [ 9.   6.  10.2  6.   7.5  6.   9.6  5.4 12.   3. ]
# A: (11.0, 9.0)
# B: (16.0, 6.0)
# P_A: (11.0, 10.2)
# P_B: (18.0, 6.0)
# A_A: (11.0, 7.5)
# A_B: (13.5, 6.0)
# S_A: (10.0, 9.6)
# S_B: (17.0, 5.4)
# C_A: (6.0, 12.0)
# C_B: (21.0, 3.0)

# %%
df_decoys = pd.DataFrame()

df_decoys = getDecoys_Pos_FixSim(df_decoys, 2500, 500, 12, 3)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 90, 75, 170, 100)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 350, 80, 12, 4)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 20000, 5300, 12, 3)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 18, 12, 24, 6)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 120, 60, 15, 4)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 3000, 1300, 3, 0.4)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 21, 14, 70, 30)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 1500, 1000, 15, 3)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 12000, 10000, 10, 6)

df_decoys = getDecoys_Pos_FixSim(df_decoys, 250, 40, 36, 6)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 40, 20, 24, 6)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 99, 70, 600, 400)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 33, 10, 36, 12)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 20000, 12000, 50000, 30000)

df_decoys = getDecoys_Pos_FixSim(df_decoys, 12, 3, 18, 6)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 2800, 1200, 1900, 1200)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 40, 13, 16, 2)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 90, 42, 60, 20)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 12, 7, 24, 12)

df_decoys = getDecoys_Pos_FixSim(df_decoys, 90, 20, 700, 300)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 160, 100, 45, 15)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 16, 4, 12, 6)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 1000, 100, 390, 120)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 100, 40, 30, 12)

df_decoys = getDecoys_Pos_FixSim(df_decoys, 900, 250, 90, 20)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 12, 3, 480, 300)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 25, 10, 300, 200)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 60, 30, 6000, 3800)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 350, 200, 16, 4)

df_decoys = getDecoys_Pos_FixSim(df_decoys, 21, 9, 900, 300)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 12, 3, 15, 3)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 30, 12, 3500, 2300)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 9, 3, 24, 6)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 3000, 1800, 3, 1.5)

df_decoys = getDecoys_Pos_FixSim(df_decoys, 21, 6, 12, 3)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 120, 60, 9, 3)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 1800, 600, 6, 1)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 190, 100, 7, 1)
df_decoys = getDecoys_Pos_FixSim(df_decoys, 45, 20, 100, 40)
# Out:
# [1166.6666666666665, 1833.3333333333335, 1166.6666666666665, 2100.0, 1166.6666666666665, 1500.0000000000002, 1033.3333333333333, 1966.6666666666667, 500, 2500], [9.0, 6.0, 10.2, 6.0, 7.5, 6.0, 9.6, 5.4, 12, 3]
# [80.0, 85.0, 80.0, 87.0, 80.0, 82.5, 79.0, 86.0, 75, 90], [146.66666666666666, 123.33333333333333, 156.0, 123.33333333333333, 135.0, 123.33333333333333, 151.33333333333331, 118.66666666666666, 170, 100]
# [170.0, 260.0, 170.0, 296.0, 170.0, 215.0, 152.0, 278.0, 80, 350], [9.333333333333334, 6.666666666666666, 10.4, 6.666666666666666, 8.0, 6.666666666666666, 9.866666666666667, 6.133333333333333, 12, 4]
# [10200.0, 15100.0, 10200.0, 17060.0, 10200.0, 12650.0, 9220.0, 16080.0, 5300, 20000], [9.0, 6.0, 10.2, 6.0, 7.5, 6.0, 9.6, 5.4, 12, 3]
# [14.0, 16.0, 14.0, 16.8, 14.0, 15.0, 13.6, 16.4, 12, 18], [18.0, 12.0, 20.4, 12.0, 15.0, 12.0, 19.2, 10.8, 24, 6]
# [80.0, 100.0, 80.0, 108.0, 80.0, 90.0, 76.0, 104.0, 60, 120], [11.333333333333334, 7.666666666666666, 12.8, 7.666666666666666, 9.5, 7.666666666666666, 12.066666666666666, 6.933333333333333, 15, 4]
# [1866.6666666666665, 2433.3333333333335, 1866.6666666666665, 2660.0, 1866.6666666666665, 2150.0, 1753.3333333333333, 2546.666666666667, 1300, 3000], [2.1333333333333333, 1.2666666666666666, 2.48, 1.2666666666666666, 1.7, 1.2666666666666666, 2.3066666666666666, 1.0933333333333333, 3, 0.4]
# [16.333333333333332, 18.666666666666668, 16.333333333333332, 19.6, 16.333333333333332, 17.5, 15.866666666666665, 19.133333333333333, 14, 21], [56.666666666666664, 43.333333333333336, 62.0, 43.333333333333336, 50.0, 43.333333333333336, 59.33333333333333, 40.66666666666667, 70, 30]
# [1166.6666666666667, 1333.3333333333333, 1166.6666666666667, 1400.0, 1166.6666666666667, 1250.0, 1133.3333333333335, 1366.6666666666665, 1000, 1500], [11.0, 7.0, 12.6, 7.0, 9.0, 7.0, 11.8, 6.2, 15, 3]
# [10666.666666666666, 11333.333333333334, 10666.666666666666, 11600.0, 10666.666666666666, 11000.0, 10533.333333333332, 11466.666666666668, 10000, 12000], [8.666666666666666, 7.333333333333333, 9.2, 7.333333333333333, 7.999999999999999, 7.333333333333333, 8.933333333333334, 7.066666666666666, 10, 6]
# [110.0, 180.0, 110.0, 208.0, 110.0, 145.0, 96.0, 194.0, 40, 250], [26.0, 16.0, 30.0, 16.0, 21.0, 16.0, 28.0, 14.0, 36, 6]
# [26.666666666666668, 33.333333333333336, 26.666666666666668, 36.0, 26.666666666666668, 30.000000000000004, 25.333333333333336, 34.66666666666667, 20, 40], [18.0, 12.0, 20.4, 12.0, 15.0, 12.0, 19.2, 10.8, 24, 6]
# [79.66666666666667, 89.33333333333333, 79.66666666666667, 93.2, 79.66666666666667, 84.5, 77.73333333333333, 91.26666666666667, 70, 99], [533.3333333333334, 466.6666666666667, 560.0, 466.6666666666667, 500.00000000000006, 466.6666666666667, 546.6666666666667, 453.33333333333337, 600, 400]
# [17.666666666666668, 25.333333333333332, 17.666666666666668, 28.4, 17.666666666666668, 21.5, 16.133333333333333, 26.866666666666667, 10, 33], [28.0, 20.0, 31.2, 20.0, 24.0, 20.0, 29.6, 18.4, 36, 12]
# [14666.666666666666, 17333.333333333332, 14666.666666666666, 18400.0, 14666.666666666666, 15999.999999999998, 14133.333333333332, 17866.666666666664, 12000, 20000], [43333.333333333336, 36666.666666666664, 46000.0, 36666.666666666664, 40000.0, 36666.666666666664, 44666.66666666667, 35333.33333333333, 50000, 30000]
# [6.0, 9.0, 6.0, 10.2, 6.0, 7.5, 5.4, 9.6, 3, 12], [14.0, 10.0, 15.6, 10.0, 12.0, 10.0, 14.8, 9.2, 18, 6]
# [1733.3333333333335, 2266.6666666666665, 1733.3333333333335, 2480.0, 1733.3333333333335, 1999.9999999999998, 1626.6666666666667, 2373.333333333333, 1200, 2800], [1666.6666666666667, 1433.3333333333333, 1760.0, 1433.3333333333333, 1550.0, 1433.3333333333333, 1713.3333333333335, 1386.6666666666665, 1900, 1200]
# [22.0, 31.0, 22.0, 34.6, 22.0, 26.5, 20.2, 32.8, 13, 40], [11.333333333333332, 6.666666666666667, 13.2, 6.666666666666667, 8.999999999999998, 6.666666666666667, 12.266666666666666, 5.733333333333333, 16, 2]
# [58.0, 74.0, 58.0, 80.4, 58.0, 66.0, 54.8, 77.2, 42, 90], [46.666666666666664, 33.333333333333336, 52.0, 33.333333333333336, 40.0, 33.333333333333336, 49.33333333333333, 30.666666666666668, 60, 20]
# [8.666666666666666, 10.333333333333334, 8.666666666666666, 11.0, 8.666666666666666, 9.5, 8.333333333333332, 10.666666666666668, 7, 12], [20.0, 16.0, 21.6, 16.0, 18.0, 16.0, 20.8, 15.2, 24, 12]
# [43.33333333333333, 66.66666666666667, 43.33333333333333, 76.0, 43.33333333333333, 55.00000000000001, 38.666666666666664, 71.33333333333334, 20, 90], [566.6666666666666, 433.33333333333337, 620.0, 433.33333333333337, 499.99999999999994, 433.33333333333337, 593.3333333333333, 406.6666666666667, 700, 300]
# [120.0, 140.0, 120.0, 148.0, 120.0, 130.0, 116.0, 144.0, 100, 160], [35.0, 25.0, 39.0, 25.0, 30.0, 25.0, 37.0, 23.0, 45, 15]
# [8.0, 12.0, 8.0, 13.6, 8.0, 10.0, 7.2, 12.8, 4, 16], [10.0, 8.0, 10.8, 8.0, 9.0, 8.0, 10.4, 7.6, 12, 6]
# [400.0, 700.0, 400.0, 820.0, 400.0, 550.0, 340.0, 760.0, 100, 1000], [300.0, 210.0, 336.0, 210.0, 255.0, 210.0, 318.0, 192.0, 390, 120]
# [60.0, 80.0, 60.0, 88.0, 60.0, 70.0, 56.0, 84.0, 40, 100], [24.0, 18.0, 26.4, 18.0, 21.0, 18.0, 25.2, 16.8, 30, 12]
# [466.66666666666663, 683.3333333333334, 466.66666666666663, 770.0, 466.66666666666663, 575.0, 423.3333333333333, 726.6666666666667, 250, 900], [66.66666666666667, 43.33333333333333, 76.0, 43.33333333333333, 55.00000000000001, 43.33333333333333, 71.33333333333334, 38.666666666666664, 90, 20]
# [6.0, 9.0, 6.0, 10.2, 6.0, 7.5, 5.4, 9.6, 3, 12], [420.0, 360.0, 444.0, 360.0, 390.0, 360.0, 432.0, 348.0, 480, 300]
# [15.0, 20.0, 15.0, 22.0, 15.0, 17.5, 14.0, 21.0, 10, 25], [266.6666666666667, 233.33333333333334, 280.0, 233.33333333333334, 250.00000000000003, 233.33333333333334, 273.33333333333337, 226.66666666666669, 300, 200]
# [40.0, 50.0, 40.0, 54.0, 40.0, 45.0, 38.0, 52.0, 30, 60], [5266.666666666667, 4533.333333333333, 5560.0, 4533.333333333333, 4900.0, 4533.333333333333, 5413.333333333334, 4386.666666666666, 6000, 3800]
# [250.0, 300.0, 250.0, 320.0, 250.0, 275.0, 240.0, 310.0, 200, 350], [12.0, 8.0, 13.6, 8.0, 10.0, 8.0, 12.8, 7.2, 16, 4]
# [13.0, 17.0, 13.0, 18.6, 13.0, 15.0, 12.2, 17.8, 9, 21], [700.0, 500.0, 780.0, 500.0, 600.0, 500.0, 740.0, 460.0, 900, 300]
# [6.0, 9.0, 6.0, 10.2, 6.0, 7.5, 5.4, 9.6, 3, 12], [11.0, 7.0, 12.6, 7.0, 9.0, 7.0, 11.8, 6.2, 15, 3]
# [18.0, 24.0, 18.0, 26.4, 18.0, 21.0, 16.8, 25.2, 12, 30], [3100.0, 2700.0, 3260.0, 2700.0, 2900.0, 2700.0, 3180.0, 2620.0, 3500, 2300]
# [5.0, 7.0, 5.0, 7.8, 5.0, 6.0, 4.6, 7.4, 3, 9], [18.0, 12.0, 20.4, 12.0, 15.0, 12.0, 19.2, 10.8, 24, 6]
# [2200.0, 2600.0, 2200.0, 2760.0, 2200.0, 2400.0, 2120.0, 2680.0, 1800, 3000], [2.5, 2.0, 2.7, 2.0, 2.25, 2.0, 2.6, 1.9, 3, 1.5]
# [11.0, 16.0, 11.0, 18.0, 11.0, 13.5, 10.0, 17.0, 6, 21], [9.0, 6.0, 10.2, 6.0, 7.5, 6.0, 9.6, 5.4, 12, 3]
# [80.0, 100.0, 80.0, 108.0, 80.0, 90.0, 76.0, 104.0, 60, 120], [7.0, 5.0, 7.8, 5.0, 6.0, 5.0, 7.4, 4.6, 9, 3]
# [1000.0, 1400.0, 1000.0, 1560.0, 1000.0, 1200.0, 920.0, 1480.0, 600, 1800], [4.333333333333333, 2.666666666666667, 5.0, 2.666666666666667, 3.4999999999999996, 2.666666666666667, 4.666666666666666, 2.3333333333333335, 6, 1]
# [130.0, 160.0, 130.0, 172.0, 130.0, 145.0, 124.0, 166.0, 100, 190], [5.0, 3.0, 5.8, 3.0, 4.0, 3.0, 5.4, 2.6, 7, 1]
# [28.333333333333336, 36.666666666666664, 28.333333333333336, 40.0, 28.333333333333336, 32.5, 26.666666666666668, 38.33333333333333, 20, 45], [80.0, 60.0, 88.0, 60.0, 70.0, 60.0, 84.0, 56.0, 100, 40]

# %%
df_decoys[["S_A", "S_B"]].head(40)
# Out:
#                      S_A                   S_B
# 0         (1033.33, 9.6)        (1966.67, 5.4)
# 1         (79.0, 151.33)        (86.0, 118.67)
# 2          (152.0, 9.87)         (278.0, 6.13)
# 3          (9220.0, 9.6)        (16080.0, 5.4)
# 4           (13.6, 19.2)          (16.4, 10.8)
# 5          (76.0, 12.07)         (104.0, 6.93)
# 6        (1753.33, 2.31)       (2546.67, 1.09)
# 7         (15.87, 59.33)        (19.13, 40.67)
# 8        (1133.33, 11.8)        (1366.67, 6.2)
# 9       (10533.33, 8.93)      (11466.67, 7.07)
# 10          (96.0, 28.0)         (194.0, 14.0)
# 11         (25.33, 19.2)         (34.67, 10.8)
# 12       (77.73, 546.67)       (91.27, 453.33)
# 13         (16.13, 29.6)         (26.87, 18.4)
# 14  (14133.33, 44666.67)  (17866.67, 35333.33)
# 15           (5.4, 14.8)            (9.6, 9.2)
# 16    (1626.67, 1713.33)    (2373.33, 1386.67)
# 17         (20.2, 12.27)          (32.8, 5.73)
# 18         (54.8, 49.33)         (77.2, 30.67)
# 19          (8.33, 20.8)         (10.67, 15.2)
# 20       (38.67, 593.33)       (71.33, 406.67)
# 21         (116.0, 37.0)         (144.0, 23.0)
# 22           (7.2, 10.4)           (12.8, 7.6)
# 23        (340.0, 318.0)        (760.0, 192.0)
# 24          (56.0, 25.2)          (84.0, 16.8)
# 25       (423.33, 71.33)       (726.67, 38.67)
# 26          (5.4, 432.0)          (9.6, 348.0)
# 27        (14.0, 273.33)        (21.0, 226.67)
# 28       (38.0, 5413.33)       (52.0, 4386.67)
# 29         (240.0, 12.8)          (310.0, 7.2)
# 30         (12.2, 740.0)         (17.8, 460.0)
# 31           (5.4, 11.8)            (9.6, 6.2)
# 32        (16.8, 3180.0)        (25.2, 2620.0)
# 33           (4.6, 19.2)           (7.4, 10.8)
# 34         (2120.0, 2.6)         (2680.0, 1.9)
# 35           (10.0, 9.6)           (17.0, 5.4)
# 36           (76.0, 7.4)          (104.0, 4.6)
# 37         (920.0, 4.67)        (1480.0, 2.33)
# 38          (124.0, 5.4)          (166.0, 2.6)
# 39         (26.67, 84.0)         (38.33, 56.0)

# %%
""" 
df_decoys_neg = pd.DataFrame()

df_decoys_neg = getDecoys_neg2(df_decoys_neg, 3.5, 2, .9, .3)
df_decoys_neg = getDecoys_neg2(df_decoys_neg, 6, 3, 32, 25)
df_decoys_neg = getDecoys_neg2(df_decoys_neg, 18, 9, 260, 150)
df_decoys_neg = getDecoys_neg2(df_decoys_neg, 12, 3, 42, 26)

df_decoys_neg.head(10)
"""
# Out:
# ' \ndf_decoys_neg = pd.DataFrame()\n\ndf_decoys_neg = getDecoys_neg2(df_decoys_neg, 3.5, 2, .9, .3)\ndf_decoys_neg = getDecoys_neg2(df_decoys_neg, 6, 3, 32, 25)\ndf_decoys_neg = getDecoys_neg2(df_decoys_neg, 18, 9, 260, 150)\ndf_decoys_neg = getDecoys_neg2(df_decoys_neg, 12, 3, 42, 26)\n\ndf_decoys_neg.head(10)\n'

# %%
""" 
# Visualization of decoys (negative-monotonic)

# Item '0' in the table above.
x = np.array([2.5, 3, 2.3, 3, 2.75, 3, 2.6, 2.9, 2, 3.5])
y = np.array([0.7, 0.5, 0.7, 0.42, 0.7, 0.6, 0.66, 0.54, 0.9, 0.3])

plt.subplots(figsize=(10, 7))
plt.scatter(x, y)
plt.annotate("A", (x[0], y[0]))
plt.annotate("B", (x[1], y[1]))
plt.annotate("P_A", (x[2], y[2]))
plt.annotate("P_B", (x[3], y[3]))
plt.annotate("A_A", (x[4], y[4]))
plt.annotate("A_B", (x[5], y[5]))
plt.annotate("S_A", (x[6], y[6]))
plt.annotate("S_B", (x[7], y[7]))
plt.annotate("C_A", (x[8], y[8]))
plt.annotate("C_B", (x[9], y[9]))

plt.show()
"""
# Out:
# ' \n# Visualization of decoys (negative-monotonic)\n\n# Item \'0\' in the table above.\nx = np.array([2.5, 3, 2.3, 3, 2.75, 3, 2.6, 2.9, 2, 3.5])\ny = np.array([0.7, 0.5, 0.7, 0.42, 0.7, 0.6, 0.66, 0.54, 0.9, 0.3])\n\nplt.subplots(figsize=(10, 7))\nplt.scatter(x, y)\nplt.annotate("A", (x[0], y[0]))\nplt.annotate("B", (x[1], y[1]))\nplt.annotate("P_A", (x[2], y[2]))\nplt.annotate("P_B", (x[3], y[3]))\nplt.annotate("A_A", (x[4], y[4]))\nplt.annotate("A_B", (x[5], y[5]))\nplt.annotate("S_A", (x[6], y[6]))\nplt.annotate("S_B", (x[7], y[7]))\nplt.annotate("C_A", (x[8], y[8]))\nplt.annotate("C_B", (x[9], y[9]))\n\nplt.show()\n'

# %%
"""
df_decoys_pos = pd.DataFrame()

df_decoys_pos = getDecoys_pos(df_decoys_pos, 2500, 500, 12, 3)
df_decoys_pos = getDecoys_pos(df_decoys_pos, 90, 75, 170, 100)
df_decoys_pos = getDecoys_pos(df_decoys_pos, 350, 80, 12, 4)
df_decoys_pos = getDecoys_pos(df_decoys_pos, 20000, 5300, 12, 3)
df_decoys_pos = getDecoys_pos(df_decoys_pos, 18, 12, 24, 6)
df_decoys_pos = getDecoys_pos(df_decoys_pos, 120, 60, 15, 4)
df_decoys_pos = getDecoys_pos(df_decoys_pos, 3000, 1300, 3, 0.4)
df_decoys_pos = getDecoys_pos(df_decoys_pos, 21, 14, 70, 30)
#df_decoys_pos = getDecoys_pos(df_decoys_pos, 1500, 500, 3.5, 2)

df_decoys_pos.head(10)

"""
# Out:
# '\ndf_decoys_pos = pd.DataFrame()\n\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 2500, 500, 12, 3)\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 90, 75, 170, 100)\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 350, 80, 12, 4)\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 20000, 5300, 12, 3)\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 18, 12, 24, 6)\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 120, 60, 15, 4)\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 3000, 1300, 3, 0.4)\ndf_decoys_pos = getDecoys_pos(df_decoys_pos, 21, 14, 70, 30)\n#df_decoys_pos = getDecoys_pos(df_decoys_pos, 1500, 500, 3.5, 2)\n\ndf_decoys_pos.head(10)\n\n'

# %%
"""
df_decoys_neg = pd.DataFrame()

df_decoys_neg = getDecoys_neg(df_decoys_neg, 3.5, 2, .9, .3)
df_decoys_neg = getDecoys_neg(df_decoys_neg, 6, 3, 32, 25)
df_decoys_neg = getDecoys_neg(df_decoys_neg, 18, 9, 260, 150)
df_decoys_neg = getDecoys_neg(df_decoys_neg, 12, 3, 42, 26)

df_decoys_neg.head(10)
"""
# Out:
# '\ndf_decoys_neg = pd.DataFrame()\n\ndf_decoys_neg = getDecoys_neg(df_decoys_neg, 3.5, 2, .9, .3)\ndf_decoys_neg = getDecoys_neg(df_decoys_neg, 6, 3, 32, 25)\ndf_decoys_neg = getDecoys_neg(df_decoys_neg, 18, 9, 260, 150)\ndf_decoys_neg = getDecoys_neg(df_decoys_neg, 12, 3, 42, 26)\n\ndf_decoys_neg.head(10)\n'

# %%
"""
def getDecoys_neg(df, d1_max, d1_min, d2_max, d2_min):
    
    # Get range difference between max-min attributes
    r1 = d1_max - d1_min 
    r2 = d2_max - d2_min 
    
    # Get item 'A'
    A1 = d1_min + (r1/3) 
    A2 = d2_max - (r2/3)
    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"
    
    # Get item 'B'
    B1 = d1_max - (r1/3)
    B2 = d2_min + (r2/3)
    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"
    
    # Get Phantom decoy A (P_A)
    P_A1 = d1_min + (r1/5)
    P_A2 = d2_max - (r2/3)
    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"
    
    # Get P_B
    P_B1 = d1_max - (r1/3)
    P_B2 = d2_min + (r2/5)
    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"
    
    # Get Attraction decoy A (A_A)
    A_A1 = A1 + (r1/6)
    A_A2 = A2
    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"
    
    # Get A_B
    A_B1 = B1
    A_B2 = B2 + (r2/6)
    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"

    # Get Similarity decoy A (S_A)
    S_A1 = A1 + (r1/15)
    S_A2 = A2 - (r2/15)
    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"
    
    # Get S_B 
    S_B1 = B1 - (r1/15)
    S_B2 = B2 + (r2/15)
    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"
    
    # Get Compromise decoy A (C_A)
    C_A1 = d1_min
    C_A2 = d2_max
    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"
    
    # Get C_B 
    C_B1 = d1_max
    C_B2 = d2_min
    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"
    
    decoy_data = pd.DataFrame(data={'A': A, 'B': B, 'P_A': P_A, 'P_B': P_B, 'A_A': A_A, 'A_B': A_B, 'S_A': S_A, 'S_B': S_B, 'C_A': C_A, 'C_B': C_B}, index=range(1))
    df = df.append(decoy_data, ignore_index = True)
    
    return df

def getDecoys_pos(df, d1_max, d1_min, d2_max, d2_min):
    
    # Get range difference between max-min attributes
    r1 = d1_max - d1_min 
    r2 = d2_max - d2_min 
    
    #c = (1/3) 
    
    # Get item 'A'
    A1 = d1_min + (r1/3) 
    A2 = d2_max - (r2/3)
    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"
    
    # Get item 'B'
    B1 = d1_max - (r1/3)
    B2 = d2_min + (r2/3)
    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"
    
    # Get Phantom decoy A (P_A)
    P_A1 = d1_min + (r1/3)
    P_A2 = d2_max - (r2/5)
    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"
    
    # Get P_B
    P_B1 = d1_max - (r1/5)
    P_B2 = d2_min + (r2/3)
    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"
    
    # Get Attraction decoy A (A_A)
    A_A1 = A1 - (r1/6)
    A_A2 = A2
    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"
    
    # Get A_B
    A_B1 = B1
    A_B2 = B2 - (r2/6)
    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"

    # Get Similarity decoy A (S_A)
    S_A1 = A1 + (r1/15)
    S_A2 = A2 - (r2/15)
    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"
    
    # Get S_B 
    S_B1 = B1 - (r1/15)
    S_B2 = B2 + (r2/15)
    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"
    
    # Get Compromise decoy A (C_A)
    C_A1 = d1_min
    C_A2 = d2_max
    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"
    
    # Get C_B 
    C_B1 = d1_max
    C_B2 = d2_min
    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"
    
    decoy_data = pd.DataFrame(data={'A': A, 'B': B, 'P_A': P_A, 'P_B': P_B, 'A_A': A_A, 'A_B': A_B, 'S_A': S_A, 'S_B': S_B, 'C_A': C_A, 'C_B': C_B}, index=range(1))
    df = df.append(decoy_data, ignore_index = True)
    
    return df
    
"""
# Out:
# '\ndef getDecoys_neg(df, d1_max, d1_min, d2_max, d2_min):\n    \n    # Get range difference between max-min attributes\n    r1 = d1_max - d1_min \n    r2 = d2_max - d2_min \n    \n    # Get item \'A\'\n    A1 = d1_min + (r1/3) \n    A2 = d2_max - (r2/3)\n    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"\n    \n    # Get item \'B\'\n    B1 = d1_max - (r1/3)\n    B2 = d2_min + (r2/3)\n    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"\n    \n    # Get Phantom decoy A (P_A)\n    P_A1 = d1_min + (r1/5)\n    P_A2 = d2_max - (r2/3)\n    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"\n    \n    # Get P_B\n    P_B1 = d1_max - (r1/3)\n    P_B2 = d2_min + (r2/5)\n    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"\n    \n    # Get Attraction decoy A (A_A)\n    A_A1 = A1 + (r1/6)\n    A_A2 = A2\n    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"\n    \n    # Get A_B\n    A_B1 = B1\n    A_B2 = B2 + (r2/6)\n    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"\n\n    # Get Similarity decoy A (S_A)\n    S_A1 = A1 + (r1/15)\n    S_A2 = A2 - (r2/15)\n    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"\n    \n    # Get S_B \n    S_B1 = B1 - (r1/15)\n    S_B2 = B2 + (r2/15)\n    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"\n    \n    # Get Compromise decoy A (C_A)\n    C_A1 = d1_min\n    C_A2 = d2_max\n    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"\n    \n    # Get C_B \n    C_B1 = d1_max\n    C_B2 = d2_min\n    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"\n    \n    decoy_data = pd.DataFrame(data={\'A\': A, \'B\': B, \'P_A\': P_A, \'P_B\': P_B, \'A_A\': A_A, \'A_B\': A_B, \'S_A\': S_A, \'S_B\': S_B, \'C_A\': C_A, \'C_B\': C_B}, index=range(1))\n    df = df.append(decoy_data, ignore_index = True)\n    \n    return df\n\ndef getDecoys_pos(df, d1_max, d1_min, d2_max, d2_min):\n    \n    # Get range difference between max-min attributes\n    r1 = d1_max - d1_min \n    r2 = d2_max - d2_min \n    \n    #c = (1/3) \n    \n    # Get item \'A\'\n    A1 = d1_min + (r1/3) \n    A2 = d2_max - (r2/3)\n    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"\n    \n    # Get item \'B\'\n    B1 = d1_max - (r1/3)\n    B2 = d2_min + (r2/3)\n    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"\n    \n    # Get Phantom decoy A (P_A)\n    P_A1 = d1_min + (r1/3)\n    P_A2 = d2_max - (r2/5)\n    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"\n    \n    # Get P_B\n    P_B1 = d1_max - (r1/5)\n    P_B2 = d2_min + (r2/3)\n    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"\n    \n    # Get Attraction decoy A (A_A)\n    A_A1 = A1 - (r1/6)\n    A_A2 = A2\n    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"\n    \n    # Get A_B\n    A_B1 = B1\n    A_B2 = B2 - (r2/6)\n    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"\n\n    # Get Similarity decoy A (S_A)\n    S_A1 = A1 + (r1/15)\n    S_A2 = A2 - (r2/15)\n    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"\n    \n    # Get S_B \n    S_B1 = B1 - (r1/15)\n    S_B2 = B2 + (r2/15)\n    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"\n    \n    # Get Compromise decoy A (C_A)\n    C_A1 = d1_min\n    C_A2 = d2_max\n    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"\n    \n    # Get C_B \n    C_B1 = d1_max\n    C_B2 = d2_min\n    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"\n    \n    decoy_data = pd.DataFrame(data={\'A\': A, \'B\': B, \'P_A\': P_A, \'P_B\': P_B, \'A_A\': A_A, \'A_B\': A_B, \'S_A\': S_A, \'S_B\': S_B, \'C_A\': C_A, \'C_B\': C_B}, index=range(1))\n    df = df.append(decoy_data, ignore_index = True)\n    \n    return df\n    \n'

# %%
"""
def getDecoys_neg2(df, d1_max, d1_min, d2_max, d2_min):
    
    # Get range difference between max-min attributes
    r1 = d1_max - d1_min 
    r2 = d2_max - d2_min 
    
    # Get item 'A'
    A1 = d1_min + (r1/3) 
    A2 = d2_min + 2*(r2/3)
    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"
    
    # Get item 'B'
    B1 = d1_min + 2*(r1/3)
    B2 = d2_min + (r2/3)
    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"
    
    # Get Phantom decoy A (P_A)
    P_A1 = d1_min + (r1/5)
    P_A2 = d2_min + 2*(r2/3)
    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"
    
    # Get P_B
    P_B1 = d1_min + 2*(r1/3)
    P_B2 = d2_min + (r2/5)
    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"
    
    # Get Attraction decoy A (A_A)
    A_A1 = A1 + (r1/6)
    A_A2 = A2
    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"
    
    # Get A_B
    A_B1 = B1
    A_B2 = B2 + (r2/6)
    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"

    # Get Similarity decoy A (S_A)
    S_A1 = A1 + (r1/15)
    S_A2 = A2 - (r2/15)
    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"
    
    # Get S_B 
    S_B1 = B1 - (r1/15)
    S_B2 = B2 + (r2/15)
    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"
    
    # Get Compromise decoy A (C_A)
    C_A1 = d1_min
    C_A2 = d2_max
    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"
    
    # Get C_B 
    C_B1 = d1_max
    C_B2 = d2_min
    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"
    
    decoy_data = pd.DataFrame(data={'A': A, 'B': B, 'P_A': P_A, 'P_B': P_B, 'A_A': A_A, 'A_B': A_B, 'S_A': S_A, 'S_B': S_B, 'C_A': C_A, 'C_B': C_B}, index=range(1))
    df = df.append(decoy_data, ignore_index = True)
    
    return df
"""
# Out:
# '\ndef getDecoys_neg2(df, d1_max, d1_min, d2_max, d2_min):\n    \n    # Get range difference between max-min attributes\n    r1 = d1_max - d1_min \n    r2 = d2_max - d2_min \n    \n    # Get item \'A\'\n    A1 = d1_min + (r1/3) \n    A2 = d2_min + 2*(r2/3)\n    A = "(" + str(round(A1, 2)) + ", " + str(round(A2, 2)) + ")"\n    \n    # Get item \'B\'\n    B1 = d1_min + 2*(r1/3)\n    B2 = d2_min + (r2/3)\n    B = "(" + str(round(B1, 2)) + ", " + str(round(B2, 2)) + ")"\n    \n    # Get Phantom decoy A (P_A)\n    P_A1 = d1_min + (r1/5)\n    P_A2 = d2_min + 2*(r2/3)\n    P_A = "(" + str(round(P_A1, 2)) + ", " + str(round(P_A2, 2)) + ")"\n    \n    # Get P_B\n    P_B1 = d1_min + 2*(r1/3)\n    P_B2 = d2_min + (r2/5)\n    P_B = "(" + str(round(P_B1, 2)) + ", " + str(round(P_B2, 2)) + ")"\n    \n    # Get Attraction decoy A (A_A)\n    A_A1 = A1 + (r1/6)\n    A_A2 = A2\n    A_A = "(" + str(round(A_A1, 2)) + ", " + str(round(A_A2, 2)) + ")"\n    \n    # Get A_B\n    A_B1 = B1\n    A_B2 = B2 + (r2/6)\n    A_B = "(" + str(round(A_B1, 2)) + ", " + str(round(A_B2, 2)) + ")"\n\n    # Get Similarity decoy A (S_A)\n    S_A1 = A1 + (r1/15)\n    S_A2 = A2 - (r2/15)\n    S_A = "(" + str(round(S_A1, 2)) + ", " + str(round(S_A2, 2)) + ")"\n    \n    # Get S_B \n    S_B1 = B1 - (r1/15)\n    S_B2 = B2 + (r2/15)\n    S_B = "(" + str(round(S_B1, 2)) + ", " + str(round(S_B2, 2)) + ")"\n    \n    # Get Compromise decoy A (C_A)\n    C_A1 = d1_min\n    C_A2 = d2_max\n    C_A = "(" + str(round(C_A1, 2)) + ", " + str(round(C_A2, 2)) + ")"\n    \n    # Get C_B \n    C_B1 = d1_max\n    C_B2 = d2_min\n    C_B = "(" + str(round(C_B1, 2)) + ", " + str(round(C_B2, 2)) + ")"\n    \n    decoy_data = pd.DataFrame(data={\'A\': A, \'B\': B, \'P_A\': P_A, \'P_B\': P_B, \'A_A\': A_A, \'A_B\': A_B, \'S_A\': S_A, \'S_B\': S_B, \'C_A\': C_A, \'C_B\': C_B}, index=range(1))\n    df = df.append(decoy_data, ignore_index = True)\n    \n    return df\n'
